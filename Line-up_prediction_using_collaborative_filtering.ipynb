# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_recommenders as tfrs
from typing import Dict, Text
import os

from sklearn.model_selection import train_test_split

#from sklearn.preprocessing import OneHotEncoder
"""from google.colab import drive
drive.mount('/content/drive')
ds_path = '/content/drive/MyDrive/Data_Mining_Project/Datasets/'"""
ds_path = 'Datasets/'
assert os.path.exists(ds_path)



features = ['home_0','home_1','home_2','home_3','home_4','away_0','away_1','away_2','away_3','away_4']

df = pd.DataFrame()
# Load data from matchups-2007.csv to matchups-2012.csv and append them to df
for i in range(2007, 2013):
    df1 = pd.read_csv(ds_path + "matchups-" + str(i) + ".csv")[features]
    print(len(df1))
    df = pd.concat([df, df1])
df.reset_index(drop=True, inplace=True)
print(f"len of final df: {len(df)}")
print("first print \n" + str(df))
print(df.shape)
# Out:
# 27500
# 26593
# 26407
# 26344
# 26447
# 21241
# len of final df: 154532
# first print
#                  home_0            home_1            home_2            home_3  \
# 0          Andrew Bynum        Lamar Odom       Luke Walton     Sasha Vujacic
# 1          Andrew Bynum        Lamar Odom       Luke Walton     Sasha Vujacic
# 2            Lamar Odom       Luke Walton     Maurice Evans      Ronny Turiaf
# 3            Lamar Odom       Luke Walton     Maurice Evans      Ronny Turiaf
# 4           Luke Walton     Maurice Evans      Ronny Turiaf      Smush Parker
# ...                 ...               ...               ...               ...
# 154527  Bismack Biyombo  Gerald Henderson      Jamario Moon      Kemba Walker
# 154528  Bismack Biyombo  Gerald Henderson      Jamario Moon      Kemba Walker
# 154529  Bismack Biyombo     Byron Mullens     Derrick Brown  Gerald Henderson
# 154530  Bismack Biyombo     Derrick Brown  Gerald Henderson      Kemba Walker
# 154531  Bismack Biyombo     Derrick Brown  Gerald Henderson      Kemba Walker
#
#                      home_4             away_0           away_1  \
# 0              Smush Parker         Boris Diaw      Kurt Thomas
# 1              Smush Parker  Amar'e Stoudemire  Leandro Barbosa
# 2              Smush Parker  Amar'e Stoudemire  Leandro Barbosa
# 3              Smush Parker         Boris Diaw      James Jones
# 4       Vladimir Radmanovic         Boris Diaw      James Jones
# ...                     ...                ...              ...
# 154527         Tyrus Thomas    Al-Farouq Aminu      Carl Landry
# 154528         Tyrus Thomas    Al-Farouq Aminu  Greivis Vasquez
# 154529         Kemba Walker    Al-Farouq Aminu  Greivis Vasquez
# 154530         Tyrus Thomas    Al-Farouq Aminu  Greivis Vasquez
# 154531         Tyrus Thomas    Al-Farouq Aminu      Carl Landry
#
#                  away_2           away_3           away_4
# 0             Raja Bell     Shawn Marion       Steve Nash
# 1             Raja Bell     Shawn Marion       Steve Nash
# 2             Raja Bell     Shawn Marion       Steve Nash
# 3           Kurt Thomas  Leandro Barbosa     Marcus Banks
# 4           Kurt Thomas  Leandro Barbosa     Marcus Banks
# ...                 ...              ...              ...
# 154527  Greivis Vasquez      Jason Smith  Marco Belinelli
# 154528     Gustavo Ayon      Jason Smith  Marco Belinelli
# 154529     Gustavo Ayon      Jason Smith  Marco Belinelli
# 154530     Gustavo Ayon      Jason Smith  Marco Belinelli
# 154531  Greivis Vasquez     Gustavo Ayon  Marco Belinelli
#
# [154532 rows x 10 columns]
# (154532, 10)

# %%
# Flatten the DataFrame slice into a single array of player names
player_names_array = df[["home_0", "home_1", "home_2", "home_3", "home_4", "away_0", "away_1", "away_2", "away_3", "away_4"]].values.flatten()

# Find the unique player names in the array
unique_player_names = np.unique(player_names_array)
print(unique_player_names)
# Out:
# ['A.J. Price' 'Aaron Brooks' 'Aaron Gray' 'Aaron McKie' 'Aaron Williams'
#  'Acie Law' 'Adam Morrison' 'Adonal Foyle' 'Adrian Griffin'
#  'Al Harrington' 'Al Horford' 'Al Jefferson' 'Al Thornton'
#  'Al-Farouq Aminu' 'Alan Anderson' 'Alan Henderson' 'Alando Tucker'
#  'Alec Burks' 'Alex Acker' 'Alexander Johnson' 'Alexis Ajinca' 'Allan Ray'
#  'Allen Iverson' 'Alonzo Gee' 'Alonzo Mourning' 'Alvin Williams'
#  "Amar'e Stoudemire" 'Amir Johnson' 'Anderson Varejao' 'Andray Blatche'
#  'Andre Barrett' 'Andre Brown' 'Andre Emmett' 'Andre Iguodala'
#  'Andre Miller' 'Andre Owens' 'Andrea Bargnani' 'Andreas Glyniadakis'
#  'Andrei Kirilenko' 'Andres Nocioni' 'Andrew Bogut' 'Andrew Bynum'
#  'Andrew Goudelock' 'Andris Biedrins' 'Andy Rautins' 'Anfernee Hardaway'
#  'Antawn Jamison' 'Anthony Carter' 'Anthony Johnson' 'Anthony Morrow'
#  'Anthony Parker' 'Anthony Randolph' 'Anthony Roberson' 'Anthony Tolliver'
#  'Antoine Walker' 'Antoine Wright' 'Antonio Anderson' 'Antonio Daniels'
#  'Antonio McDyess' 'Armon Johnson' 'Arron Afflalo' 'Austin Croshere'
#  'Austin Daye' 'Avery Bradley' 'Awvee Storey' 'Baron Davis' 'Ben Gordon'
#  'Ben Uzoh' 'Ben Wallace' 'Beno Udrih' 'Bernard Robinson' 'Billy Thomas'
#  'Bismack Biyombo' 'Blake Ahearn' 'Blake Griffin' 'Bo Outlaw'
#  'Bobby Brown' 'Bobby Jackson' 'Bobby Jones' 'Bobby Simmons' 'Bonzi Wells'
#  'Boris Diaw' 'Bostjan Nachbar' 'Bracey Wright' 'Brad Miller'
#  'Brandan Wright' 'Brandon Bass' 'Brandon Jennings' 'Brandon Knight'
#  'Brandon Roy' 'Brandon Rush' 'Brendan Haywood' 'Brent Barry'
#  'Brevin Knight' 'Brian Cardinal' 'Brian Cook' 'Brian Scalabrine'
#  'Brian Skinner' 'Brook Lopez' 'Bruce Bowen' 'Byron Mullens' 'C.J. Miles'
#  'C.J. Watson' 'Calvin Booth' 'Carl Landry' 'Carldell Johnson'
#  'Carlos Arroyo' 'Carlos Boozer' 'Carlos Delfino' 'Carmelo Anthony'
#  'Caron Butler' 'Cartier Martin' 'Casey Jacobsen' 'Cedric Bozeman'
#  'Cedric Jackson' 'Cedric Simmons' 'Chandler Parsons' 'Channing Frye'
#  'Charles Jenkins' 'Charlie Bell' 'Charlie Villanueva' 'Chase Budinger'
#  'Chauncey Billups' 'Cheikh Samb' 'Chris Andersen' 'Chris Bosh'
#  'Chris Douglas-Roberts' 'Chris Duhon' 'Chris Hunter' 'Chris Johnson'
#  'Chris Kaman' 'Chris McCray' 'Chris Mihm' 'Chris Paul' 'Chris Quinn'
#  'Chris Richard' 'Chris Singleton' 'Chris Webber' 'Chris Wilcox'
#  'Chris Wright' 'Christian Eyenga' 'Chuck Hayes' 'Chucky Atkins'
#  'Clifford Robinson' 'Coby Karl' 'Cole Aldrich' 'Corey Brewer'
#  'Corey Maggette' 'Corliss Williamson' 'Cory Higgins' 'Cory Joseph'
#  'Courtney Fortson' 'Courtney Lee' 'Courtney Sims' 'Craig Brackins'
#  'Craig Smith' 'Cuttino Mobley' 'D.J. Augustin' 'D.J. Kennedy'
#  'D.J. Strawberry' 'D.J. White' 'DaJuan Summers' 'Daequan Cook'
#  'Dahntay Jones' 'Dajuan Wagner' 'Dale Davis' 'Damien Wilkins'
#  'Damion James' 'Damir Markota' 'Damon Jones' 'Damon Stoudamire'
#  'Dan Dickau' 'Dan Gadzuric' 'Daniel Ewing' 'Daniel Gibson' 'Daniel Orton'
#  'Danilo Gallinari' 'Danny Fortson' 'Danny Granger' 'Danny Green'
#  'Dante Cunningham' 'Darington Hobson' 'Darius Miles' 'Darius Morris'
#  'Darius Songaila' 'Darius Washington' 'Darko Milicic' 'Darnell Jackson'
#  'Darrell Armstrong' 'Darrell Arthur' 'Darren Collison' 'Darrick Martin'
#  'Darryl Watkins' 'David Andersen' 'David Harrison' 'David Lee'
#  'David Noel' 'David Wesley' 'David West' 'DeAndre Jordan'
#  'DeAndre Liggins' 'DeJuan Blair' 'DeMar DeRozan' 'DeMarcus Cousins'
#  'DeMarcus Nelson' 'DeMarre Carroll' 'DeSagana Diop' 'DeShawn Stevenson'
#  'Dee Brown' 'Delonte West' 'Demetris Nichols' 'Dennis Horner'
#  'DerMarr Johnson' 'Derek Anderson' 'Derek Fisher' 'Deron Williams'
#  'Derrick Brown' 'Derrick Byars' 'Derrick Caracter' 'Derrick Favors'
#  'Derrick Rose' 'Derrick Williams' 'Desmon Farmer' 'Desmond Mason'
#  'Devean George' 'Devin Brown' 'Devin Ebanks' 'Devin Harris'
#  'Dexter Pittman' 'Didier Ilunga-Mbenga' 'Dijon Thompson'
#  'Dikembe Mutombo' 'Dirk Nowitzki' 'Dominic McGuire' 'Dominique Jones'
#  'Donald Sloan' 'Donell Taylor' 'Donte Greene' 'Dontell Jefferson'
#  'Donyell Marshall' 'Dorell Wright' 'Doug Christie' 'Drew Gooden'
#  'Dwayne Jones' 'Dwight Howard' 'Dwyane Wade' "E'Twaun Moore"
#  'Earl Barron' 'Earl Boykins' 'Earl Clark' 'Earl Watson' 'Ed Davis'
#  'Eddie Gill' 'Eddie Griffin' 'Eddie House' 'Eddie Jones' 'Eddy Curry'
#  'Eduardo Najera' 'Edwin Ubiles' 'Ekpe Udoh' 'Elliot Williams'
#  'Elton Brand' 'Emeka Okafor' 'Enes Kanter' 'Eric Bledsoe' 'Eric Dawson'
#  'Eric Gordon' 'Eric Maynor' 'Eric Piatkowski' 'Eric Snow' 'Eric Williams'
#  'Erick Dampier' 'Ersan Ilyasova' 'Esteban Batista' 'Etan Thomas'
#  'Eugene Jeter' 'Evan Turner' 'Fabricio Oberto' 'Francisco Elson'
#  'Francisco Garcia' 'Fred Jones' 'Gabe Pruitt' 'Gani Lawal' 'Garret Siler'
#  'Garrett Temple' 'Gary Forbes' 'Gary Neal' 'Gary Payton' 'George Hill'
#  'Gerald Green' 'Gerald Henderson' 'Gerald Wallace' 'Gilbert Arenas'
#  'Glen Davis' 'Goran Dragic' 'Gordan Giricek' 'Gordon Hayward'
#  'Grant Hill' 'Greg Buckner' 'Greg Monroe' 'Greg Oden' 'Greg Smith'
#  'Greg Stiemsma' 'Greivis Vasquez' 'Guillermo Diaz' 'Gustavo Ayon'
#  'Hakim Warrick' "Hamady N'Diaye" 'Hamed Haddadi' 'Hasheem Thabeet'
#  'Hassan Adams' 'Hassan Whiteside' 'Hedo Turkoglu' 'Henry Walker'
#  'Hilton Armstrong' 'Ian Mahinmi' 'Ike Diogu' 'Iman Shumpert' 'Ime Udoka'
#  'Ira Newble' 'Isaiah Thomas' 'Ish Smith' 'Ivan Johnson' 'Ivan McFarlin'
#  'J.J. Barea' 'J.J. Hickson' 'J.J. Redick' 'J.R. Giddens' 'J.R. Smith'
#  'JaJuan Johnson' 'JaVale McGee' 'Jackie Butler' 'Jacque Vaughn'
#  'Jake Tsakalidis' 'Jake Voskuhl' 'Jalen Rose' 'Jamaal Magloire'
#  'Jamaal Tinsley' 'Jamal Crawford' 'Jamal Sampson' 'Jamario Moon'
#  'Jameer Nelson' 'James Anderson' 'James Augustine' 'James Harden'
#  'James Johnson' 'James Jones' 'James Lang' 'James Posey'
#  'James Singleton' 'James White' 'Jan Vesely' 'Jannero Pargo'
#  'Jared Dudley' 'Jared Jeffries' 'Jared Reiner' 'Jarrett Jack'
#  'Jarron Collins' 'Jarvis Hayes' 'Jason Collins' 'Jason Hart'
#  'Jason Kapono' 'Jason Kidd' 'Jason Maxiell' 'Jason Richardson'
#  'Jason Smith' 'Jason Terry' 'Jason Thompson' 'Jason Williams'
#  'Javaris Crittenton' 'Jawad Williams' 'Jeff Adrien' 'Jeff Ayres'
#  'Jeff Foote' 'Jeff Foster' 'Jeff Green' 'Jeff McInnis' 'Jeff Teague'
#  'Jelani McCoy' 'Jeremy Evans' 'Jeremy Lin' 'Jeremy Pargo'
#  'Jeremy Richardson' 'Jeremy Tyler' "Jermaine O'Neal" 'Jermaine Taylor'
#  'Jermareo Davidson' 'Jerome Dyson' 'Jerome James' 'Jerome Jordan'
#  'Jerry Smith' 'Jerry Stackhouse' 'Jerryd Bayless' 'Jimmer Fredette'
#  'Jimmy Butler' 'Joakim Noah' 'Jodie Meeks' 'Joe Alexander' 'Joe Crawford'
#  'Joe Johnson' 'Joe Smith' 'Joel Anthony' 'Joel Przybilla' 'Joey Dorsey'
#  'Joey Graham' 'Johan Petro' 'John Lucas III' 'John Salmons' 'John Wall'
#  'Jon Brockman' 'Jon Leuer' 'Jonas Jerebko' 'Jonathan Bender'
#  'Jonny Flynn' 'Jordan Crawford' 'Jordan Farmar' 'Jordan Hamilton'
#  'Jordan Hill' 'Jordan Williams' 'Jorge Garbajosa' 'Jose Calderon'
#  'Josh Boone' 'Josh Childress' 'Josh Davis' 'Josh Harrellson'
#  'Josh Howard' 'Josh McRoberts' 'Josh Powell' 'Josh Selby' 'Josh Smith'
#  'Jrue Holiday' 'Juan Carlos Navarro' 'Juan Dixon' 'Julian Wright'
#  'Julius Hodge' 'Julyan Stone' 'Jumaine Jones' 'Junior Harrington'
#  'Justin Dentmon' 'Justin Harper' 'Justin Reed' 'Justin Williams'
#  'Juwan Howard' 'Kaniel Dickens' 'Kareem Rush' 'Kasib Powell'
#  'Kawhi Leonard' 'Keith Benson' 'Keith Bogans' 'Keith Langford'
#  'Keith McLeod' 'Kelenna Azubuike' 'Kelvin Cato' 'Kemba Walker'
#  'Kendrick Perkins' 'Kenneth Faried' 'Kenny Thomas' 'Kenyon Martin'
#  'Kevin Durant' 'Kevin Garnett' 'Kevin Love' 'Kevin Martin' 'Kevin Ollie'
#  'Kevin Seraphin' 'Kevin Willis' 'Kevinn Pinkney' 'Keyon Dooling'
#  'Kirk Hinrich' 'Kirk Snyder' 'Klay Thompson' 'Kobe Bryant' 'Kosta Koufos'
#  'Kosta Perovic' 'Kris Humphries' 'Kurt Thomas' 'Kwame Brown'
#  'Kyle Korver' 'Kyle Lowry' 'Kyle Weaver' 'Kyrie Irving' 'Kyrylo Fesenko'
#  'LaMarcus Aldridge' 'Lamar Odom' 'Lance Allred' 'Lance Stephenson'
#  'Lance Thomas' 'Landry Fields' 'Larry Hughes' 'Larry Owens'
#  'Larry Sanders' 'Lavoy Allen' 'Lawrence Roberts' 'Lazar Hayward'
#  'LeBron James' 'Leandro Barbosa' 'Leon Powe' 'Lester Hudson'
#  'Linas Kleiza' 'Lindsey Hunter' 'Linton Johnson' 'Loren Woods'
#  'Lorenzen Wright' 'Lou Amundson' 'Lou Williams' 'Luc Mbah a Moute'
#  'Luis Scola' 'Luke Babbitt' 'Luke Harangody' 'Luke Jackson'
#  'Luke Ridnour' 'Luke Schenscher' 'Luke Walton' 'Luol Deng' 'Luther Head'
#  'Lynn Greer' 'Maceo Baston' 'Malcolm Lee' 'Malcolm Thomas' 'Malik Allen'
#  'Malik Hairston' 'Malik Rose' 'Manny Harris' 'Manu Ginobili'
#  'MarShon Brooks' 'Marc Gasol' 'Marc Jackson' 'Marcin Gortat'
#  'Marco Belinelli' 'Marcus Banks' 'Marcus Camby' 'Marcus Cousin'
#  'Marcus Haislip' 'Marcus Landry' 'Marcus Morris' 'Marcus Thornton'
#  'Marcus Vinicius' 'Marcus Williams' 'Mardy Collins' 'Mario Chalmers'
#  'Mario West' 'Mark Blount' 'Mark Madsen' 'Markieff Morris' 'Marko Jaric'
#  'Marquis Daniels' 'Marreese Speights' 'Martell Webster' 'Marvin Williams'
#  'Matt Barnes' 'Matt Bonner' 'Matt Carroll' 'Matt Freije' 'Matt Harpring'
#  'Maurice Ager' 'Maurice Evans' 'Maurice Taylor' 'Mehmet Okur'
#  'Melvin Ely' 'Metta World Peace' 'Michael Beasley' 'Michael Doleac'
#  'Michael Finley' 'Michael Olowokandi' 'Michael Redd' 'Michael Ruffin'
#  'Mickael Gelabale' 'Mickael Pietrus' 'Mickell Gladness' 'Mike Bibby'
#  'Mike Conley' 'Mike Dunleavy' 'Mike Hall' 'Mike Harris' 'Mike James'
#  'Mike Miller' 'Mike Sweetney' 'Mike Taylor' 'Mike Wilks' 'Mikki Moore'
#  'Mile Ilic' 'Mo Williams' 'Monta Ellis' 'Morris Almond' 'Morris Peterson'
#  'Mouhamed Sene' 'Mustafa Shakur' 'Mychel Thompson' 'Nate Robinson'
#  'Nathan Jawai' 'Nazr Mohammed' 'Nenad Krstic' 'Nene Hilario'
#  'Nick Collison' 'Nick Fazekas' 'Nick Young' 'Nicolas Batum'
#  'Nikola Pekovic' 'Nikola Vucevic' 'Nolan Smith' 'Norris Cole' 'O.J. Mayo'
#  'Oleksiy Pecherov' 'Oliver Lafayette' 'Omer Asik' 'Omri Casspi'
#  'Orien Greene' 'Othella Harrington' 'Othello Hunter' 'Othyus Jeffers'
#  'P.J. Brown' 'P.J. Tucker' 'Pape Sow' 'Pape Sy' 'Pat Burke' 'Pat Garrity'
#  'Patrick Ewing' "Patrick O'Bryant" 'Patrick Patterson' 'Patty Mills'
#  'Pau Gasol' 'Paul Davis' 'Paul George' 'Paul Millsap' 'Paul Pierce'
#  'Peja Stojakovic' 'Pops Mensah-Bonsu' 'Primoz Brezec'
#  'Quentin Richardson' 'Quincy Douby' 'Quincy Pondexter' 'Quinton Ross'
#  'Raef LaFrentz' 'Rafael Araujo' 'Rafer Alston' 'Raja Bell' 'Rajon Rondo'
#  'Ramon Sessions' 'Randolph Morris' 'Randy Foye' 'Randy Livingston'
#  'Rashad McCants' 'Rashard Lewis' 'Rasheed Wallace' 'Rasho Nesterovic'
#  'Rasual Butler' 'Rawle Marshall' 'Ray Allen' 'Raymond Felton'
#  'Reggie Evans' 'Reggie Jackson' 'Reggie Williams' 'Renaldo Balkman'
#  'Renaldo Major' 'Richard Hamilton' 'Richard Jefferson' 'Richie Frahm'
#  'Ricky Davis' 'Ricky Rubio' 'Rob Kurz' 'Robert Hite' 'Robert Horry'
#  'Robert Swift' 'Robin Lopez' 'Rodney Carney' 'Rodney Stuckey'
#  'Rodrigue Beaubois' 'Roger Mason' 'Roger Powell' 'Roko Ukic'
#  'Ronald Dupree' 'Ronald Murray' 'Ronnie Brewer' 'Ronnie Price'
#  'Ronny Turiaf' 'Roy Hibbert' 'Royal Ivey' 'Ruben Patterson'
#  'Rudy Fernandez' 'Rudy Gay' 'Russell Westbrook' 'Ryan Anderson'
#  'Ryan Bowen' 'Ryan Gomes' 'Ryan Hollins' 'Ryan Reid' 'Salim Stoudamire'
#  'Sam Cassell' 'Sam Young' 'Samardo Samuels' 'Samuel Dalembert'
#  'Sarunas Jasikevicius' 'Sasha Pavlovic' 'Sasha Vujacic' 'Scot Pollard'
#  'Scott Padgett' 'Sean Marks' 'Sean May' 'Sean Singletary' 'Sean Williams'
#  'Sebastian Telfair' 'Semih Erden' 'Serge Ibaka' 'Sergio Rodriguez'
#  'Shammond Williams' 'Shane Battier' 'Shannon Brown' "Shaquille O'Neal"
#  'Shareef Abdur-Rahim' 'Shaun Livingston' 'Shavlik Randolph'
#  'Shawn Marion' 'Shawne Williams' 'Shelden Williams' 'Shelvin Mack'
#  'Sherron Collins' 'Smush Parker' 'Solomon Alabi' 'Solomon Jones'
#  'Sonny Weems' 'Speedy Claxton' 'Spencer Hawes' 'Stanislav Medvedenko'
#  'Stephane Lasme' 'Stephen Curry' 'Stephen Graham' 'Stephen Jackson'
#  'Stephon Marbury' 'Steve Blake' 'Steve Francis' 'Steve Nash'
#  'Steve Novak' 'Steven Hill' 'Steven Hunter' 'Steven Smith'
#  'Stromile Swift' 'Sun Yue' 'Sundiata Gaines' 'T.J. Ford' 'Taj Gibson'
#  'Tarence Kinsey' 'Taurean Green' 'Taylor Griffin' 'Tayshaun Prince'
#  'Terrel Harris' 'Terrence Williams' 'Thabo Sefolosha' 'Thaddeus Young'
#  'Theo Ratliff' 'Thomas Gardner' 'Tiago Splitter' 'Tim Duncan'
#  'Tim Thomas' 'Timofey Mozgov' 'Tobias Harris' 'Toney Douglas'
#  'Tony Allen' 'Tony Battie' 'Tony Parker' 'Tracy McGrady' 'Travis Diener'
#  'Travis Leslie' 'Travis Outlaw' 'Trenton Hassell' 'Trevor Ariza'
#  'Trevor Booker' 'Trey Gilder' 'Trey Johnson' 'Trey Thompkins'
#  'Tristan Thompson' 'Troy Hudson' 'Troy Murphy' 'Ty Lawson'
#  'Tyler Hansbrough' 'Tyler Honeycutt' 'Tyreke Evans' 'Tyronn Lue'
#  'Tyrus Thomas' 'Tyson Chandler' 'Udonis Haslem' 'Uros Slokar'
#  'Vassilis Spanoulis' 'Vernon Macklin' 'Viktor Khryapa' 'Vince Carter'
#  'Vitaly Potapenko' 'Vladimir Radmanovic' 'Von Wafer' 'Walker Russell'
#  'Wally Szczerbiak' 'Walter Herrmann' 'Walter Sharpe' 'Wayne Ellington'
#  'Wayne Simien' 'Wesley Johnson' 'Wesley Matthews' 'Will Blalock'
#  'Will Bynum' 'Will Conroy' 'Will Solomon' 'Willie Green' 'Willie Warren'
#  'Wilson Chandler' 'Xavier Henry' 'Xavier Silas' 'Yakhouba Diawara'
#  'Yao Ming' 'Yaroslav Korolev' 'Yi Jianlian' 'Zabian Dowdell'
#  'Zach Randolph' 'Zaza Pachulia' 'Zydrunas Ilgauskas']

# %% [markdown]
# We can approach the task of recommending a player based on the other nine players using a simplified item-based collaborative filtering approach. This method will focus on understanding the similarities between players based on their occurrences together in lineups, without explicitly using user data or game outcomes.
#
# In a real-world scenario, this approach would involve complex similarity computations and possibly leveraging player stats, positions, or other features to find the best matches. However, for simplicity, let's create a basic example that demonstrates the concept using Python and common libraries like Pandas. This example will focus on the core idea of recommending a player based on the presence of other players, assuming we have pre-computed some form of similarity scores between players or we derive similarity from their co-occurrences.
#
# Step 1: Prepare the Data
#
# We have a DataFrame df with game lineups where each row represents a lineup and contains the names of nine players (excluding the player to be predicted). In a real setup, we also have data on player performances, positions, etc., but here we'll keep it to player names for simplicity.
#
# Step 2: Compute Similarity Scores
#
# Let's assume a basic method to compute similarity: the number of times players appear together.
#
# Step 3: Recommend a Player
#
# The recommendation for the missing player can be based on the most similar players to the given lineup of nine players, leveraging the computed similarity scores.

# %%
# First approach: a simplified item-based collaborative filtering

# Function to recommend a player based on a lineup and similarity_scores
def recommend_player(current_lineup, similarity_scores):
    recommended_candidates = defaultdict(int)
    for player in current_lineup:
        for pair, score in similarity_scores.items():
            if player in pair:
                recommended_candidates[pair[1 if pair[0] == player else 0]] += score
    # Sort candidates based on their scores
    recommended_sorted = sorted(recommended_candidates.items(), key=lambda x: x[1], reverse=True)
    # Return the top recommended player not already in the lineup
    for recommendation, _ in recommended_sorted:
        if recommendation not in current_lineup:
            return recommendation
    return None  # In case no recommendation is found

# Example
#current_lineup = X_test.iloc[110,:9]  # Up to 9 players
#print(current_lineup)
#recommended_player = recommend_player(current_lineup)
#print(f"Recommended player to add: {recommended_player}, True player: {X_test.iloc[110,9]}")

# %%
from collections import defaultdict

accuracy_list = []

for a_seed in range(100, 102):
    X_train, X_test = train_test_split(df[["home_0", "home_1", "home_2", "home_3", "home_4",
                                           "away_0", "away_1", "away_2", "away_3", "away_4"]], test_size=0.2, random_state=a_seed)

    
    similarity_scores = defaultdict(int)
    
    for index, row in X_train.iterrows():
        players = row.values
        #print(players)
        for player in players:
            for other_player in players:
                if player != other_player:
                    similarity_scores[tuple(sorted((player, other_player)))] += 1 # it reduces the memory by half.
    print()
    print(f"len(similarity_scores): {len(similarity_scores)}")




    correct_recommendations = 0
    total_recommendations = 0
    
    total_recommendations_to_make = len(X_test) * 10
    # Iterate over the test dataset
    for index, row in X_test.iterrows():
        players = row.values
        for target_player in players:
            current_lineup = [player for player in players if player != target_player]
            recommended_player = recommend_player(current_lineup, similarity_scores)
            if recommended_player == target_player:
                correct_recommendations += 1
            total_recommendations += 1
    
        progress = f"{total_recommendations}/{total_recommendations_to_make}: accuracy: {correct_recommendations/total_recommendations}"
        print(f"\rProgress: {progress}", end='', flush=True)
    
    # Calculate and print the accuracy
    accuracy = correct_recommendations / total_recommendations
    print()
    print(f"Accuracy: {accuracy:.4f}")
    accuracy_list.append(accuracy)

print()
print()
print(f"Accuracy: {np.mean(accuracy_list):.4f}, std: {np.std(accuracy_list):.4f}")
# Out:
# len(similarity_scores): 163589
# Progress: 309070/309070: accuracy: 0.13590125214352736
# Accuracy: 0.1359
#
# len(similarity_scores): 163609
# Progress: 309070/309070: accuracy: 0.13731193580742226
# Accuracy: 0.1373
#
#
# Accuracy: 0.1366, std: 0.0007

# %% [markdown]
# 1. Iterate over each row in the test dataset (X_test).
# 2. For each row, iterate over each player in that row as the target player.
# 3. Remove the target player from the lineup, leaving the other nine players.
# 4. Call the recommend_player() function with these nine players.
# 5. Check if the recommended player matches the target player. If it does, count this as a correct recommendation.
# 6. Calculate the accuracy of the model as the ratio of correct recommendations to the total number of recommendations made.
